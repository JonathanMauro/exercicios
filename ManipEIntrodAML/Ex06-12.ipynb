# %% [markdown]
# 1. Importe o banco de dados anexo nesta aula;

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn. model_selection import train_test_split
from sklearn.linear_model import LinearRegression
pd.set_option('display.max_columns', 21)
pd.set_option('display.precision', 2)

# %%
df = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# 2. Mostre as 5 primeiras linhas;

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode    lat    long  \
# ...

# %% [markdown]
# 3. Mostre as colunas e o índice do dataset;

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=21613, step=1)

# %% [markdown]
# 4. Mostre o shape do dataset;

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# 5. Mostre informações do objeto criado com a função info();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# 6. Mostre o dtype de cada coluna;

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# 7. Remova as seguintes colunas: 'id', 'date', 'zipcode', 'lat', 'long';

# %%
col = ['id', 'date', 'zipcode', 'lat', 'long']
df2 = df.drop(labels = col, axis = 1, inplace= True)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %% [markdown]
# 8. Verifique se há missing data no dataset;

# %%
df.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# 9. Mostre estatísticas descritivas do dataset com a função describe();

# %%
df.describe().round(2).T
# Out:
#                  count       mean        std      min        25%        50%  \
# price          21613.0  540088.14  367127.20  75000.0  321950.00  450000.00
# bedrooms       21613.0       3.37       0.93      0.0       3.00       3.00
# bathrooms      21613.0       2.11       0.77      0.0       1.75       2.25
# sqft_living    21613.0    2079.90     918.44    290.0    1427.00    1910.00
# sqft_lot       21613.0   15106.97   41420.51    520.0    5040.00    7618.00
# floors         21613.0       1.49       0.54      1.0       1.00       1.50
# waterfront     21613.0       0.01       0.09      0.0       0.00       0.00
# view           21613.0       0.23       0.77      0.0       0.00       0.00
# condition      21613.0       3.41       0.65      1.0       3.00       3.00
# grade          21613.0       7.66       1.18      1.0       7.00       7.00
# sqft_above     21613.0    1788.39     828.09    290.0    1190.00    1560.00
# ...

# %% [markdown]
# 10. Calcule a matriz de correlação;

# %%
df.corr()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price           1.00  3.08e-01       0.53         0.70  8.97e-02  2.57e-01
# bedrooms        0.31  1.00e+00       0.52         0.58  3.17e-02  1.75e-01
# bathrooms       0.53  5.16e-01       1.00         0.75  8.77e-02  5.01e-01
# sqft_living     0.70  5.77e-01       0.75         1.00  1.73e-01  3.54e-01
# sqft_lot        0.09  3.17e-02       0.09         0.17  1.00e+00 -5.20e-03
# floors          0.26  1.75e-01       0.50         0.35 -5.20e-03  1.00e+00
# waterfront      0.27 -6.58e-03       0.06         0.10  2.16e-02  2.37e-02
# view            0.40  7.95e-02       0.19         0.28  7.47e-02  2.94e-02
# condition       0.04  2.85e-02      -0.12        -0.06 -8.96e-03 -2.64e-01
# grade           0.67  3.57e-01       0.66         0.76  1.14e-01  4.58e-01
# sqft_above      0.61  4.78e-01       0.69         0.88  1.84e-01  5.24e-01
# ...

# %% [markdown]
# 11. Calcule a matriz de covariância;

# %%
df.cov()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.35e+11  1.05e+05   1.48e+05     2.37e+08  1.36e+09  5.09e+04
# bedrooms       1.05e+05  8.65e-01   3.70e-01     4.93e+02  1.22e+03  8.81e-02
# bathrooms      1.48e+05  3.70e-01   5.93e-01     5.34e+02  2.80e+03  2.08e-01
# sqft_living    2.37e+08  4.93e+02   5.34e+02     8.44e+05  6.57e+06  1.76e+02
# sqft_lot       1.36e+09  1.22e+03   2.80e+03     6.57e+06  1.72e+09 -1.16e+02
# floors         5.09e+04  8.81e-02   2.08e-01     1.76e+02 -1.16e+02  2.92e-01
# waterfront     8.46e+03 -5.30e-04   4.25e-03     8.25e+00  7.74e+01  1.11e-03
# view           1.12e+05  5.67e-02   1.11e-01     2.00e+02  2.37e+03  1.22e-02
# condition      8.69e+03  1.72e-02  -6.26e-02    -3.51e+01 -2.41e+02 -9.27e-02
# grade          2.88e+05  3.90e-01   6.02e-01     8.23e+02  5.53e+03  2.91e-01
# sqft_above     1.84e+08  3.68e+02   4.37e+02     6.67e+05  6.29e+06  2.34e+02
# ...

# %% [markdown]
# 12. Faça um mapa de calor com base na matriz de correlação, use o módulo Seaborn;

# %%
corr = df.corr()

# %%
plt.figure(figsize= (10, 10))
sns.heatmap(corr, cmap = 'Blues', annot = True);

# %% [markdown]
# 13. Faça um gráfico das relações entre as variáveis do dataset com a função pairplot do módulo Seaborn;

# %%
sns.pairplot(df)

# %% [markdown]
# 14. Defina a variável target (coluna 'price') e armazene em uma variável;
# 15. Defina as variáveis preditoras, que serão utilizadas para explicar o preço, e armazene em uma variável;

# %%
y = df['price']
x = df.drop('price', axis = 1)

# %% [markdown]
# 16. Use a função train_test_split do sklearn para separar o dataset em dados de treino e teste, defina o test_size = 0.3 e random_state = 33;

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state= 33)

# %% [markdown]
# 17. Crie um modelo de regressão linear e ajuste aos dados de treino, use: from sklearn.linear_model import LinearRegression;

# %%
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 18. Calcule o coeficiente de determinação do modelo com a função score(), passando os dados de teste;

# %%
modelo.score(X_test, y_test)
# Out:
# 0.6496675233034923
