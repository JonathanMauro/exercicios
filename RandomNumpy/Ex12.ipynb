# %% [markdown]
# Use a função np.random.randn() para gerar um array com números aleatórios de uma distribuição normal padrão, de shape 30 x 3. Seguidamente, crie um DataFrame com os dados criados e gere uma visualização da distribuição de probabilidade de cada coluna com o módulo Seaborn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random
import pandas as pd

# %%
arr = random.randn(30, 3)

# %%
df = pd.DataFrame(data = arr, columns = list('ABC'))

# %%
df.head()
# Out:
#           A         B         C
# 0  0.004929  0.528164  1.367202
# 1  1.225420  2.611423  0.052965
# 2 -0.175246  1.019635 -0.493536
# 3  0.486896  1.381063 -0.234437
# 4  0.336477 -1.515085 -2.073476

# %%
sns.displot(df)
plt.show()

# %%
sns.displot(df, kind = 'kde')
plt.show()
