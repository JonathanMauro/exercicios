# %% [markdown]
# Construa o DataFrame abaixo. Use o NumPy para construir os dados das colunas, com a função np.random.normal(), considere uma distribuição com média 10 e desvio padrão 0.5. Utilize Compreensão em Listas para configurar os índices e as colunas.
#
# https://prnt.sc/Rju50AivFwZM

# %%
import numpy as np
import pandas as pd

# %%
array = np.random.normal(10, 0.5, (10,10)).round(1)
col = [chr(64+i) for i in range(1, array.shape[1]+1)]
index = [chr(64+i)+str(i) for i in range(1,array.shape[0]+1)]
df = pd.DataFrame(data = array, columns = col, index= index)
df
# Out:
#         A     B     C     D     E     F     G     H     I     J
# A1   10.2  10.1   9.8   8.7  10.7  10.0  10.9  10.3  10.1  10.1
# B2   10.5  10.4  10.3  10.7  10.0  10.4  10.1   9.9   9.8  10.2
# C3    8.6   9.6   9.3   9.9   9.8   9.7   9.1   9.6  10.4  10.1
# D4    9.9   8.9  10.1   9.9   9.8   9.8   9.4  10.7  10.6   9.5
# E5    9.6  10.0   9.0  10.4  10.3   9.2  10.8   9.6  10.2   9.7
# F6   10.2  11.1  10.3   9.7   9.7  10.0   9.3   9.3   9.3   9.8
# G7   10.1  10.5   9.4   9.8  11.2   9.9   9.8  10.2   9.5  10.4
# H8   10.1   9.9  10.9   9.2  10.6   9.8  10.9   9.5  10.2  10.2
# I9   10.2   9.6  10.7  10.6  10.0   9.9   9.4   9.4   9.7  10.9
# J10   9.9  10.5  10.5  10.0  10.8   9.4  10.6   9.9  10.6   9.6
