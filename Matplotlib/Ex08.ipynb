# %% [markdown]
# Com os dados abaixo construa um histograma. Use a função plt.hist().
#
#
#
#
# import numpy as np
#
# data = np.random.normal(loc = 100, scale = 0.5, size = 100)
#
#
#
# Resultado esperado:
#
# https://prnt.sc/sSeTcI5SIkzQ

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(loc = 100, scale = 0.5, size = 100)

# %%
plt.hist(data)
plt.title('Histogram')
plt.xlabel('Data')
plt.show()
